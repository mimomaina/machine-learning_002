#        '1959-06-26', '1959-06-27', '1959-06-28', '1959-06-29',
#        '1959-06-30', '1959-07-01', '1959-07-02', '1959-07-03',
#        '1959-07-04', '1959-07-05', '1959-07-06', '1959-07-07',
#        '1959-07-08', '1959-07-09', '1959-07-10', '1959-07-11',
#        '1959-07-12', '1959-07-13', '1959-07-14', '1959-07-15',
#        '1959-07-16', '1959-07-17', '1959-07-18', '1959-07-19',
#        '1959-07-20', '1959-07-21', '1959-07-22', '1959-07-23',
#        '1959-07-24', '1959-07-25', '1959-07-26', '1959-07-27',
#        '1959-07-28', '1959-07-29', '1959-07-30', '1959-07-31',
#        '1959-08-01', '1959-08-02', '1959-08-03', '1959-08-04',
#        '1959-08-05', '1959-08-06', '1959-08-07', '1959-08-08',
#        '1959-08-09', '1959-08-10', '1959-08-11', '1959-08-12',
#        '1959-08-13', '1959-08-14', '1959-08-15', '1959-08-16',
#        '1959-08-17', '1959-08-18', '1959-08-19', '1959-08-20',
#        '1959-08-21', '1959-08-22', '1959-08-23', '1959-08-24',
#        '1959-08-25', '1959-08-26', '1959-08-27', '1959-08-28',
#        '1959-08-29', '1959-08-30', '1959-08-31', '1959-09-01',
#        '1959-09-02', '1959-09-03', '1959-09-04', '1959-09-05',
#        '1959-09-06', '1959-09-07', '1959-09-08', '1959-09-09',
#        '1959-09-10', '1959-09-11', '1959-09-12', '1959-09-13',
#        '1959-09-14', '1959-09-15', '1959-09-16', '1959-09-17',
#        '1959-09-18', '1959-09-19', '1959-09-20', '1959-09-21',
#        '1959-09-22', '1959-09-23', '1959-09-24', '1959-09-25',
#        '1959-09-26', '1959-09-27', '1959-09-28', '1959-09-29',
#        '1959-09-30', '1959-10-01', '1959-10-02', '1959-10-03',
#        '1959-10-04', '1959-10-05', '1959-10-06', '1959-10-07',
#        '1959-10-08', '1959-10-09', '1959-10-10', '1959-10-11',
#        '1959-10-12', '1959-10-13', '1959-10-14', '1959-10-15',
#        '1959-10-16', '1959-10-17', '1959-10-18', '1959-10-19',
#        '1959-10-20', '1959-10-21', '1959-10-22', '1959-10-23',
#        '1959-10-24', '1959-10-25', '1959-10-26', '1959-10-27',
#        '1959-10-28', '1959-10-29', '1959-10-30', '1959-10-31',
#        '1959-11-01', '1959-11-02', '1959-11-03', '1959-11-04',
#        '1959-11-05', '1959-11-06', '1959-11-07', '1959-11-08',
#        '1959-11-09', '1959-11-10', '1959-11-11', '1959-11-12',
#        '1959-11-13', '1959-11-14', '1959-11-15', '1959-11-16',
#        '1959-11-17', '1959-11-18', '1959-11-19', '1959-11-20',
#        '1959-11-21', '1959-11-22', '1959-11-23', '1959-11-24',
#        '1959-11-25', '1959-11-26', '1959-11-27', '1959-11-28',
#        '1959-11-29', '1959-11-30', '1959-12-01', '1959-12-02',
#        '1959-12-03', '1959-12-04', '1959-12-05', '1959-12-06',
#        '1959-12-07', '1959-12-08', '1959-12-09', '1959-12-10',
#        '1959-12-11', '1959-12-12', '1959-12-13', '1959-12-14',
#        '1959-12-15', '1959-12-16', '1959-12-17', '1959-12-18',
#        '1959-12-19', '1959-12-20', '1959-12-21', '1959-12-22',
#        '1959-12-23', '1959-12-24', '1959-12-25', '1959-12-26',
#        '1959-12-27', '1959-12-28', '1959-12-29', '1959-12-30',
#        '1959-12-31'], dtype=object)

# %%
#convert Date to DateTime
df['date']= pd.to_datetime(df['date'])

# %%
#setting frequency

# %% [markdown]
# # Setting time/date column as index

# %%
df.set_index('date', inplace=True)

# %% [markdown]
# # Visualising

# %%
# Plot births over time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['births'], label='births', color='blue')
plt.title('Births Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Number of Births', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Checking for stationarity

# %% [markdown]
# p-value>0.05 (non-stationary)
# p-value <= 0.05 ( stationary)

# %%
#Augmented Dickey-Fuller (ADF) test
result = adfuller(df['births'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -4.808291253559765
# p-value: 5.2434129901498554e-05

# %% [markdown]
# p-value < 0.05 . Reject null hypothesis.(Data is stationary)

# %% [markdown]
# # Decomposing time series

# %% [markdown]
# Check for trend, seasonality, cyclical,noise

# %%
decompose_result = seasonal_decompose(df['births'], model='multiplicative', period=12)

# %%
decompose_result = seasonal_decompose(df['births'], model='additive', period=12)

# %%
# Plot decomposition
plt.rcParams.update({'figure.figsize': (10, 8)})
decompose_result.plot()
plt.show()

# %% [markdown]
# # ACF & PACF Plot

# %%
# Plot ACF
plt.figure(figsize=(10, 5))
plot_acf(df['births'], lags=40, alpha=0.05)
plt.title('Autocorrelation Function (ACF)', fontsize=14)
plt.show()

# %%
# Plot PACF
plt.figure(figsize=(10, 5))
plot_pacf(df['births'], lags=40, alpha=0.05, method='ywm')  # Use 'ywm' for PACF calculations
plt.title('Partial Autocorrelation Function (PACF)', fontsize=14)
plt.show()

# %% [markdown]
# # Train &Test split data(chronologically)

# %%
split_ratio = 0.8
split_index = int(len(df) * split_ratio)
train = df['births'][:split_index]
test = df['births'][split_index:]

# %%
print(f"Training data length: {len(train)}, Testing data length: {len(test)}")
# Out:
# Training data length: 292, Testing data length: 73

# %% [markdown]
# # Modelling

# %% [markdown]
# Low AIC, BIC, low MAE

# %%
model = ARIMA(train, order=(1, 0, 1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 births   No. Observations:                  292
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -988.202
# Date:                Tue, 14 Jan 2025   AIC                           1984.404
# Time:                        06:25:15   BIC                           1999.111
# Sample:                    01-01-1959   HQIC                          1990.295
#                          - 10-19-1959
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         42.2332      4.542      9.298      0.000      33.331      51.135
# ar.L1          0.9932      0.016     61.009      0.000       0.961       1.025
# ma.L1         -0.9447      0.041    -23.314      0.000      -1.024      -0.865
# sigma2        50.7702      3.859     13.155      0.000      43.206      58.335
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.19   Jarque-Bera (JB):                21.80
# Prob(Q):                              0.28   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.89   Skew:                             0.57
# Prob(H) (two-sided):                  0.55   Kurtosis:                         3.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# SARIMA model
sarima_model = SARIMAX(train,
                       order=(1,1,1),
                       seasonal_order=(1,1,1, 12),
                       enforce_stationarity=False,
                       enforce_invertibility=False)
sarima_results = sarima_model.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# # Forecasting

# %%
# Forecast for the test set
forecast = model_fit.forecast(steps=len(test))

# Plot actual vs forecast
plt.figure(figsize=(10, 6))
plt.plot(train, label='Train', color='blue')
plt.plot(test, label='Test', color='orange')
plt.plot(test.index, forecast, label='Forecast', color='green')
plt.legend(loc='upper left')
plt.title('ARIMA Model: Actual vs Forecast')
plt.show()

# %%
# Forecast on test data
sarima_forecast = sarima_results.forecast(steps=len(test))

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(train.index, train, label='Train', color='blue')
plt.plot(test.index, test, label='Test', color='orange')
plt.plot(test.index, sarima_forecast, label='SARIMA Forecast', color='green')
plt.legend()
plt.title('SARIMA Model: Actual vs Forecast')
plt.show()

# %% [markdown]
# # Evaluate model's performance

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(test, forecast)
rmse = np.sqrt(mse)
print(f"Mean Squared Error: {mse:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
# Out:
# Mean Squared Error: 48.59
# Root Mean Squared Error: 6.97

# %%
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(test, sarima_forecast)
rmse = np.sqrt(mse)
print(f"Mean Squared Error: {mse:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
# Out:
# Mean Squared Error: 78.64
# Root Mean Squared Error: 8.87
